# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ferna\\OneDrive\\Documents\\Courses\\Springboard data science bootcamp\\Capstone 2'

# %%
import pandas as pd

# %%
df = pd.read_excel('combined_cycle.xlsx')

# %%
df
# Out:
#          AT      V       AP     RH      PE
# 0     14.96  41.76  1024.07  73.17  463.26
# 1     25.18  62.96  1020.04  59.08  444.37
# 2      5.11  39.40  1012.16  92.14  488.56
# 3     20.86  57.32  1010.24  76.64  446.48
# 4     10.82  37.50  1009.23  96.62  473.90
# ...     ...    ...      ...    ...     ...
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28
#
# [9568 rows x 5 columns]

# %%
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
df.count()
# Out:
# AT    9568
# V     9568
# AP    9568
# RH    9568
# PE    9568
# dtype: int64

# %%
#no missing data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9568 non-null   float64
#  1   V       9568 non-null   float64
#  2   AP      9568 non-null   float64
#  3   RH      9568 non-null   float64
#  4   PE      9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
#All rows of data consist of floats and there are no categorical features

# %%
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
df.tail()
# Out:
#          AT      V       AP     RH      PE
# 9563  16.65  49.69  1014.01  91.00  460.03
# 9564  13.19  39.18  1023.67  66.78  469.62
# 9565  31.32  74.33  1012.92  36.48  429.57
# 9566  24.48  69.45  1013.86  62.39  435.74
# 9567  21.60  62.52  1017.23  67.87  453.28

# %%
#examining data with head and tail method

# %%
print(df.where(df<0).count())
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
#There are no features with values that are less than 0 therefore we dont have to drop any row.

# %%
sns.scatterplot(data=df,x=df['PE'],y=df['AT'])

# %%
#plotting Ambient Temperature vs elecctric energy output seems to show inverse relationship

# %%
sns.scatterplot(data=df,x=df['PE'],y=df['V'])

# %%
#plotting Voltage vs electric energy output seems to show a negative relationship

# %%
sns.scatterplot(data=df,x=df['PE'],y=df['AP'])

# %%
#plotting Ambient Pressure vs electric energy output doesnt seem to show a clear relationship

# %%
sns.scatterplot(data=df,x=df['PE'],y=df['RH'])

# %%
#plotting Relative Humidity vs electric energy output doesnt seem to show a clear relationship

# %%
ax = sns.boxplot(data=df, orient="h", palette="Set2")

# %%
ax = sns.boxplot(data=df['AT'], orient="h", color = "yellow")
print(df['AT'].min())
print(df['AT'].max())
# Out:
# 1.81
# 37.11

# %%
ax = sns.boxplot(data=df['V'], orient="h", color = "red")
print(df['V'].min())
print(df['V'].max())
# Out:
# 25.36
# 81.56

# %%
ax = sns.boxplot(data=df['AP'], orient="h", color = "blue")
print(df['AP'].min())
print(df['AP'].max())
# Out:
# 992.89
# 1033.3

# %%
ax = sns.boxplot(data=df['RH'], orient="h", palette="Set2")
print(df['RH'].min())
print(df['RH'].max())
# Out:
# 25.56
# 100.16

# %%
ax = sns.boxplot(data=df['PE'], orient="h", palette="Set2")
print(df['PE'].min())
print(df['PE'].max())
# Out:
# 420.26
# 495.76

# %%
#Examining each features using box plots shows that there are outliers when it comes to  the Relative Humidity and electric energy output

# %%
df.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
#examining the statistics of each feature

# %%
df.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);

# %%
#Examing the distribution of each feature

# %% [markdown]
# Key Findings:
#
# *There are no missing values in the data set.
# *All features are numerical so we can use regression algorithms to model electric energy output
# *There are no negative values which would have represented physicially impossible meausurements and thus there was no need to drop any row of data
